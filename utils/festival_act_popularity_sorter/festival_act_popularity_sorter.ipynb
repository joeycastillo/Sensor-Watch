# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from unidecode import unidecode
import json
from datetime import datetime
import difflib
from fake_useragent import UserAgent
import requests
sp = None

# %%
MAKE_ARR_FILE = 1 # 0 = Don't make the file; 1= Make the file; 2 = Make the file and print it to the console
PRINT_RANKINGs = True
USE_TEST_ARR = False
IGNORE_STAGES = False
PRINT_SEARCH_RESULTS = True
SORT_POP_BY_FOLLOWERS = False
GENRE_DEFAULT = "NO_GENRE"
STAGES = [ "T_MOBILE", "BUD_LIGHT", "PERRYS", "THE_GROVE", "LAKESHORE", "TITOS", "BMI", "MUSIC_DEN", "BACKYARD" ]
STAGE_DEFAULT = "NO_STAGE"
URL = 'https://clashfinder.com/data/event/lollapalooza2025chicago.json'

# %%
testPop = [
    {'name': '2hollis', 'followers': 243228, 'popularity': 65, 'monthly_listeners': 1024674, 'top_song': 'style', 'genre_list': ['hyperpop', 'electroclash']},
    {'name': 'A$AP Rocky', 'followers': 16258876, 'popularity': 86, 'monthly_listeners': 37586045, 'top_song': "I Smoked Away My Brain (I'm God x Demons Mashup) (feat. Imogen Heap & Clams Casino)", 'genre_list': ['rap']},
    {'name': 'Airwolf Paradise', 'followers': 13609, 'popularity': 38, 'monthly_listeners': 191620, 'top_song': 'Revolver', 'genre_list': []},
    {'name': 'Alemeda', 'followers': 50756, 'popularity': 40, 'monthly_listeners': 170585, 'top_song': 'Gonna Bleach My Eyebrows', 'genre_list': []},
    {'name': 'Alex Warren', 'followers': 1047157, 'popularity': 84, 'monthly_listeners': 27385019, 'top_song': 'Ordinary', 'genre_list': []},
    {'name': 'ALEXSUCKS', 'followers': 26456, 'popularity': 45, 'monthly_listeners': 384438, 'top_song': 'Worm in the Sun', 'genre_list': []},
    {'name': "Aliyah's Interlude", 'followers': 289521, 'popularity': 57, 'monthly_listeners': 2335373, 'top_song': 'IT GIRL', 'genre_list': []},
    {'name': 'ALLEYCVT', 'followers': 63077, 'popularity': 53, 'monthly_listeners': 474010, 'top_song': 'ONE FOR YOU', 'genre_list': ['dubstep', 'edm']},
    {'name': 'Amaarae', 'followers': 510048, 'popularity': 66, 'monthly_listeners': 5502741, 'top_song': 'SAD GIRLZ LUV MONEY Remix (feat. Kali Uchis and Moliy)', 'genre_list': ['alté', 'afrobeats']},
    {'name': 'Artemas', 'followers': 1187298, 'popularity': 77, 'monthly_listeners': 18388735, 'top_song': 'i like the way you kiss me', 'genre_list': []},
    {'name': 'Azzecca', 'followers': 24778, 'popularity': 44, 'monthly_listeners': 304787, 'top_song': 'Other Side', 'genre_list': ['tech house', 'stutter house']},
    {'name': "Barry Can't Swim", 'followers': 225955, 'popularity': 64, 'monthly_listeners': 3036482, 'top_song': 'How It Feels', 'genre_list': ['jazz house']},
    {'name': 'benches', 'followers': 48795, 'popularity': 48, 'monthly_listeners': 278265, 'top_song': 'Monodrama', 'genre_list': []},
    {'name': 'Bilmuri', 'followers': 200391, 'popularity': 61, 'monthly_listeners': 682438, 'top_song': 'BETTER HELL (Thicc boi)', 'genre_list': ['post-hardcore']},
    {'name': 'bLAck pARty', 'followers': 250377, 'popularity': 44, 'monthly_listeners': 357828, 'top_song': 'Dancing', 'genre_list': ['alternative r&b']},
    {'name': 'Bladee', 'followers': 573353, 'popularity': 69, 'monthly_listeners': 1453670, 'top_song': 'take me by the hand', 'genre_list': ['cloud rap', 'hyperpop']},
    {'name': 'Bleachers', 'followers': 844316, 'popularity': 69, 'monthly_listeners': 9041939, 'top_song': 'Margaret (feat. Bleachers)', 'genre_list': []},
    {'name': 'The Blessed Madonna', 'followers': 115639, 'popularity': 66, 'monthly_listeners': 6374173, 'top_song': 'Marea (we’ve lost dancing)', 'genre_list': []},
    {'name': 'BLK ODYSSY', 'followers': 106605, 'popularity': 54, 'monthly_listeners': 841241, 'top_song': 'GHOST RIDE', 'genre_list': []},
    {'name': 'Bo Staloch', 'followers': 19431, 'popularity': 48, 'monthly_listeners': 382491, 'top_song': 'Wait It Out', 'genre_list': []},
    {'name': 'BossMan Dlow', 'followers': 632580, 'popularity': 72, 'monthly_listeners': 5943720, 'top_song': 'Mo Chicken (feat. French Montana)', 'genre_list': []},
    {'name': 'BOYNEXTDOOR', 'followers': 1331101, 'popularity': 71, 'monthly_listeners': 2790783, 'top_song': 'IF I SAY, I LOVE YOU', 'genre_list': ['k-pop']},
    {'name': 'BUNT.', 'followers': 227348, 'popularity': 69, 'monthly_listeners': 7793318, 'top_song': 'Clouds', 'genre_list': ['stutter house']},
    {'name': 'bôa', 'followers': 1058732, 'popularity': 71, 'monthly_listeners': 10409793, 'top_song': 'Duvet', 'genre_list': []},
    {'name': 'Ca7riel y Paco Amoroso', 'followers': 317545, 'popularity': 72, 'monthly_listeners': 3057145, 'top_song': '#TETAS', 'genre_list': []},
    {'name': 'Cage The Elephant', 'followers': 4088633, 'popularity': 75, 'monthly_listeners': 15392470, 'top_song': 'Cigarette Daydreams', 'genre_list': ['modern rock']},
    {'name': 'Carol Ades', 'followers': 26405, 'popularity': 41, 'monthly_listeners': 143074, 'top_song': 'Dreams', 'genre_list': []},
    {'name': 'Caroline Kingsbury', 'followers': 20411, 'popularity': 46, 'monthly_listeners': 557598, 'top_song': 'Give Me A Sign (feat. Caroline Kingsbury)', 'genre_list': []},
    {'name': 'Carter Vail', 'followers': 110013, 'popularity': 48, 'monthly_listeners': 302796, 'top_song': 'Dirt Man', 'genre_list': []},
    {'name': 'Cassandra Coleman', 'followers': 0, 'popularity': 0, 'monthly_listeners': 0, 'top_song': 0, 'genre_list': []},
    {'name': 'Charlotte Lawrence', 'followers': 1179924, 'popularity': 57, 'monthly_listeners': 2165946, 'top_song': "Joke's On You", 'genre_list': []},
    {'name': 'Chase & Status', 'followers': 1129551, 'popularity': 71, 'monthly_listeners': 6775888, 'top_song': 'BACKBONE', 'genre_list': ['drum and bass', 'jungle']},
    {'name': 'Chicago Made', 'followers': 0, 'popularity': 0, 'monthly_listeners': 0, 'top_song': 0, 'genre_list': []},
    {'name': 'Chicago Youth Orchestra', 'followers': 134, 'popularity': 4, 'monthly_listeners': 489, 'top_song': 'Winged Creatures', 'genre_list': []},
    {'name': 'Clairo', 'followers': 5906123, 'popularity': 81, 'monthly_listeners': 17896660, 'top_song': 'Juna', 'genre_list': ['bedroom pop']},
    {'name': 'Cloonee', 'followers': 192715, 'popularity': 64, 'monthly_listeners': 3885163, 'top_song': 'Stephanie', 'genre_list': ['tech house', 'house', 'latin house', 'techno']},
    {'name': 'Colby Acuff', 'followers': 131855, 'popularity': 55, 'monthly_listeners': 1177543, 'top_song': 'If I Were the Devil', 'genre_list': ['red dirt', 'country']},
    {'name': 'The Criticals', 'followers': 20340, 'popularity': 35, 'monthly_listeners': 96217, 'top_song': 'Treat Ya Better (Original)', 'genre_list': []},
    {'name': 'Damiano David', 'followers': 433043, 'popularity': 71, 'monthly_listeners': 8788979, 'top_song': 'Born With a Broken Heart', 'genre_list': []},
    {'name': 'Daniel Allan', 'followers': 21189, 'popularity': 49, 'monthly_listeners': 708768, 'top_song': 'I Just Need (with Lyrah)', 'genre_list': ['stutter house']},
    {'name': 'The Dare', 'followers': 145353, 'popularity': 56, 'monthly_listeners': 1386244, 'top_song': 'Girls', 'genre_list': ['electroclash']},
    {'name': 'Del Water Gap', 'followers': 246678, 'popularity': 63, 'monthly_listeners': 2470831, 'top_song': 'Ode to a Conversation Stuck in Your Throat', 'genre_list': []},
    {'name': 'DJ Heather', 'followers': 1945, 'popularity': 10, 'monthly_listeners': 1572, 'top_song': "Still Here - Deez Fire Burnin' Edit", 'genre_list': ['chicago house', 'funky house']},
    {'name': 'Djo', 'followers': 1899156, 'popularity': 75, 'monthly_listeners': 21258791, 'top_song': 'End of Beginning', 'genre_list': ['psychedelic pop']},
    {'name': 'Doechii', 'followers': 2601586, 'popularity': 89, 'monthly_listeners': 57512177, 'top_song': 'Anxiety', 'genre_list': []},
    {'name': 'Dogpark', 'followers': 32147, 'popularity': 44, 'monthly_listeners': 179515, 'top_song': "Now It's Over", 'genre_list': []},
    {'name': 'Dom Dolla', 'followers': 544573, 'popularity': 72, 'monthly_listeners': 9098939, 'top_song': 'Dreamin (feat. Daya)', 'genre_list': ['house', 'tech house']},
    {'name': 'Dominic Fike', 'followers': 2068053, 'popularity': 79, 'monthly_listeners': 23747211, 'top_song': 'Love Hangover (feat. Dominic Fike)', 'genre_list': []},
    {'name': 'Dr. Fresch', 'followers': 135141, 'popularity': 52, 'monthly_listeners': 902359, 'top_song': 'Gangsta Gangsta', 'genre_list': ['g-house', 'bass house']},
    {'name': 'The Droptines', 'followers': 16750, 'popularity': 49, 'monthly_listeners': 365662, 'top_song': 'Bill of Sale', 'genre_list': ['red dirt']},
    {'name': 'Dua Saleh', 'followers': 109424, 'popularity': 46, 'monthly_listeners': 264383, 'top_song': 'Sugar Mama', 'genre_list': ['alternative r&b']},
    {'name': 'Durand Bernarr', 'followers': 122763, 'popularity': 54, 'monthly_listeners': 544556, 'top_song': 'STUCK.', 'genre_list': ['neo soul']},
    {'name': 'Eddie And The Getaway', 'followers': 87623, 'popularity': 54, 'monthly_listeners': 620176, 'top_song': 'Love Myself', 'genre_list': []},
    {'name': 'Fcukers', 'followers': 31221, 'popularity': 47, 'monthly_listeners': 343054, 'top_song': 'Bon Bon', 'genre_list': []},
    {'name': 'FINNEAS', 'followers': 2207788, 'popularity': 70, 'monthly_listeners': 8050971, 'top_song': 'Till Forever Falls Apart', 'genre_list': []},
    {'name': 'flipturn', 'followers': 225421, 'popularity': 63, 'monthly_listeners': 1836377, 'top_song': 'August', 'genre_list': []},
    {'name': 'flowerovlove', 'followers': 108764, 'popularity': 54, 'monthly_listeners': 1225680, 'top_song': 'breaking news', 'genre_list': []},
    {'name': 'Flux Pavilion', 'followers': 717570, 'popularity': 59, 'monthly_listeners': 1869462, 'top_song': "I Can't Stop", 'genre_list': ['dubstep', 'edm', 'dub']},
    {'name': 'Foster The People', 'followers': 3969044, 'popularity': 74, 'monthly_listeners': 17911723, 'top_song': 'Pumped Up Kicks', 'genre_list': []},
    {'name': 'Fujii Kaze', 'followers': 4035162, 'popularity': 75, 'monthly_listeners': 7529588, 'top_song': 'Shinunoga E-Wa', 'genre_list': ['j-pop']},
    {'name': 'Gigi Perez', 'followers': 1036895, 'popularity': 80, 'monthly_listeners': 28271289, 'top_song': 'Sailor Song', 'genre_list': []},
    {'name': 'Girl Tones', 'followers': 4085, 'popularity': 28, 'monthly_listeners': 55884, 'top_song': 'I Know You Know', 'genre_list': []},
    {'name': 'Glass Beams', 'followers': 447209, 'popularity': 54, 'monthly_listeners': 716436, 'top_song': 'Mahal', 'genre_list': []},
    {'name': 'Gracie Abrams', 'followers': 5092270, 'popularity': 89, 'monthly_listeners': 50068233, 'top_song': 'That’s So True', 'genre_list': []},
    {'name': 'Graham Barham', 'followers': 87766, 'popularity': 63, 'monthly_listeners': 2054261, 'top_song': 'OIL MONEY', 'genre_list': ['country']},
    {'name': 'Gryffin', 'followers': 984520, 'popularity': 69, 'monthly_listeners': 7509958, 'top_song': 'Desire - Gryffin Remix', 'genre_list': ['edm', 'melodic bass']},
    {'name': 'half•alive', 'followers': 723701, 'popularity': 61, 'monthly_listeners': 1536433, 'top_song': 'still feel.', 'genre_list': []},
    {'name': 'Hex Cougar', 'followers': 33350, 'popularity': 41, 'monthly_listeners': 194502, 'top_song': 'Silo (feat. fknsyd)', 'genre_list': ['future bass', 'edm trap', 'melodic bass']},
    {'name': 'hey, nothing', 'followers': 148381, 'popularity': 54, 'monthly_listeners': 563117, 'top_song': 'i haunt ur dreams', 'genre_list': ['midwest emo']},
    {'name': 'ian', 'followers': 479623, 'popularity': 71, 'monthly_listeners': 5253311, 'top_song': '3.5', 'genre_list': []},
    {'name': 'Isabel LaRosa', 'followers': 2250040, 'popularity': 74, 'monthly_listeners': 11365798, 'top_song': "i'm yours", 'genre_list': []},
    {'name': 'Isaiah Rashad', 'followers': 1551614, 'popularity': 70, 'monthly_listeners': 5275833, 'top_song': "Wat's Wrong (feat. Zacari & Kendrick Lamar)", 'genre_list': []},
    {'name': 'ISOxo', 'followers': 78609, 'popularity': 55, 'monthly_listeners': 550639, 'top_song': 'SMACK TALK', 'genre_list': ['bass house', 'edm trap', 'edm']},
    {'name': 'Jade LeMac', 'followers': 220224, 'popularity': 66, 'monthly_listeners': 3920242, 'top_song': 'Constellations', 'genre_list': []},
    {'name': 'Jane Remover', 'followers': 91519, 'popularity': 54, 'monthly_listeners': 330722, 'top_song': 'Dancing with your eyes closed', 'genre_list': ['hyperpop', 'shoegaze']},
    {'name': 'Jesse Detor', 'followers': 14661, 'popularity': 35, 'monthly_listeners': 42802, 'top_song': 'Apartment Song', 'genre_list': []},
    {'name': 'JEV', 'followers': 12231, 'popularity': 45, 'monthly_listeners': 314147, 'top_song': 'be free', 'genre_list': ['uk garage', 'rally house', 'stutter house']},
    {'name': 'jigitz', 'followers': 22868, 'popularity': 57, 'monthly_listeners': 1176625, 'top_song': 'tell you straight', 'genre_list': ['stutter house']},
    {'name': 'Joe P', 'followers': 138847, 'popularity': 49, 'monthly_listeners': 484086, 'top_song': 'Off My Mind', 'genre_list': []},
    {'name': 'Joey Valence & Brae', 'followers': 598363, 'popularity': 66, 'monthly_listeners': 3816483, 'top_song': 'PUNK TACTICS', 'genre_list': []},
    {'name': 'JPEGMAFIA', 'followers': 969083, 'popularity': 68, 'monthly_listeners': 2027101, 'top_song': 'either on or off the drugs', 'genre_list': ['experimental hip hop', 'alternative hip hop', 'experimental']},
    {'name': 'julie', 'followers': 347840, 'popularity': 56, 'monthly_listeners': 634972, 'top_song': 'flutter', 'genre_list': ['shoegaze']},
    {'name': 'Junior Varsity', 'followers': 37117, 'popularity': 49, 'monthly_listeners': 459160, 'top_song': 'Cross The Street', 'genre_list': []},
    {'name': 'Kaicrewsade', 'followers': 4155, 'popularity': 31, 'monthly_listeners': 41081, 'top_song': 'Fukizutahmbout!', 'genre_list': []},
    {'name': 'KATSEYE', 'followers': 1297660, 'popularity': 68, 'monthly_listeners': 6727964, 'top_song': 'Touch', 'genre_list': ['k-pop']},
    {'name': 'Kenny Mason', 'followers': 208431, 'popularity': 59, 'monthly_listeners': 1803809, 'top_song': 'Dance Now (feat. Kenny Mason)', 'genre_list': []},
    {'name': 'KickFlip', 'followers': 185925, 'popularity': 54, 'monthly_listeners': 498647, 'top_song': 'Mama Said', 'genre_list': ['k-pop']},
    {'name': 'Knock2', 'followers': 138329, 'popularity': 63, 'monthly_listeners': 1577219, 'top_song': 'dashstar* - VIP', 'genre_list': ['bass house', 'edm', 'bassline']},
    {'name': 'Korn', 'followers': 8819068, 'popularity': 78, 'monthly_listeners': 11752222, 'top_song': 'Freak On a Leash', 'genre_list': ['nu metal', 'metal', 'rap metal', 'alternative metal']},
    {'name': 'La Femme', 'followers': 570220, 'popularity': 60, 'monthly_listeners': 1411472, 'top_song': "Elle ne t'aime pas", 'genre_list': ['french indie pop', 'french pop', 'french house']},
    {'name': 'Laila!', 'followers': 219856, 'popularity': 55, 'monthly_listeners': 1364309, 'top_song': 'Not My Problem', 'genre_list': ['sexy drill']},
    {'name': 'Landon Barker', 'followers': 40007, 'popularity': 43, 'monthly_listeners': 101992, 'top_song': 'Friends With Your EX', 'genre_list': []},
    {'name': 'Landon Conrath', 'followers': 40536, 'popularity': 49, 'monthly_listeners': 349597, 'top_song': '2AM', 'genre_list': []},
    {'name': 'LATIN MAFIA', 'followers': 1430143, 'popularity': 76, 'monthly_listeners': 7083863, 'top_song': 'Patadas de Ahogado', 'genre_list': ['latin r&b']},
    {'name': 'LAYZ', 'followers': 30072, 'popularity': 41, 'monthly_listeners': 145042, 'top_song': 'SPARK', 'genre_list': ['riddim', 'dubstep', 'deathstep']},
    {'name': 'Lekan', 'followers': 14700, 'popularity': 39, 'monthly_listeners': 127967, 'top_song': 'Magic Gurl (feat. Lekan)', 'genre_list': []},
    {'name': 'Levity', 'followers': 91349, 'popularity': 55, 'monthly_listeners': 820240, 'top_song': 'Postman', 'genre_list': ['dubstep']},
    {'name': 'Luke Combs', 'followers': 12473606, 'popularity': 86, 'monthly_listeners': 25036035, 'top_song': "Ain't No Love In Oklahoma (From Twisters: The Album)", 'genre_list': ['country']},
    {'name': 'Magdalena Bay', 'followers': 414396, 'popularity': 68, 'monthly_listeners': 3890170, 'top_song': 'Killshot', 'genre_list': []},
    {'name': 'Mariah the Scientist', 'followers': 762758, 'popularity': 69, 'monthly_listeners': 4209706, 'top_song': 'Spread Thin', 'genre_list': ['alternative r&b']},
    {'name': 'The Marías', 'followers': 2389628, 'popularity': 83, 'monthly_listeners': 23793821, 'top_song': 'No One Noticed', 'genre_list': ['bedroom pop']},
    {'name': 'Maribou State', 'followers': 444625, 'popularity': 69, 'monthly_listeners': 4550097, 'top_song': 'Midas', 'genre_list': []},
    {'name': 'MARINA', 'followers': 5927618, 'popularity': 75, 'monthly_listeners': 10931048, 'top_song': 'Bubblegum Bitch', 'genre_list': []},
    {'name': 'Mark Ambor', 'followers': 605596, 'popularity': 72, 'monthly_listeners': 13182717, 'top_song': 'Belong Together', 'genre_list': []},
    {'name': 'Marlon Hoffstadt', 'followers': 145649, 'popularity': 64, 'monthly_listeners': 4129162, 'top_song': "It's That Time - FISHER Remix", 'genre_list': ['hard house', 'eurodance', 'hypertechno', 'techno']},
    {'name': 'Martin Garrix', 'followers': 15177414, 'popularity': 77, 'monthly_listeners': 21907142, 'top_song': 'In the Name of Love', 'genre_list': ['edm', 'electronica', 'progressive house']},
    {'name': 'Mary Droppinz', 'followers': 12342, 'popularity': 33, 'monthly_listeners': 61563, 'top_song': 'Yummy Gummy', 'genre_list': []},
    {'name': 'Matt Champion', 'followers': 174410, 'popularity': 50, 'monthly_listeners': 854164, 'top_song': 'Slow Motion', 'genre_list': ['bedroom pop']},
    {'name': 'Mau P', 'followers': 151930, 'popularity': 66, 'monthly_listeners': 5027702, 'top_song': 'Drugs From Amsterdam', 'genre_list': ['tech house', 'house']},
    {'name': 'Max McNown', 'followers': 452971, 'popularity': 72, 'monthly_listeners': 7196544, 'top_song': 'A Lot More Free', 'genre_list': []},
    {'name': 'Midnight Generation', 'followers': 84415, 'popularity': 53, 'monthly_listeners': 476469, 'top_song': "Don't Wait Up", 'genre_list': ['mexican indie', 'nu disco']},
    {'name': 'Mk.gee', 'followers': 354689, 'popularity': 64, 'monthly_listeners': 1848754, 'top_song': 'Alesis', 'genre_list': []},
    {'name': 'Montell Fish', 'followers': 1931995, 'popularity': 75, 'monthly_listeners': 10523659, 'top_song': 'Hotel', 'genre_list': []},
    {'name': 'Murda Beatz', 'followers': 167734, 'popularity': 58, 'monthly_listeners': 2540621, 'top_song': 'FEFE (feat. Nicki Minaj & Murda Beatz)', 'genre_list': []},
    {'name': 'Naomi Scott', 'followers': 383644, 'popularity': 62, 'monthly_listeners': 3658953, 'top_song': 'Speechless (Full)', 'genre_list': []},
    {'name': 'NewDad', 'followers': 131956, 'popularity': 51, 'monthly_listeners': 495951, 'top_song': 'Angel', 'genre_list': []},
    {'name': 'nimino', 'followers': 115217, 'popularity': 66, 'monthly_listeners': 5438550, 'top_song': 'I Only Smoke When I Drink', 'genre_list': ['stutter house', 'melodic house']},
    {'name': 'Nourished by Time', 'followers': 30060, 'popularity': 44, 'monthly_listeners': 242880, 'top_song': 'Hell of a Ride', 'genre_list': []},
    {'name': 'Ocean Alley', 'followers': 621739, 'popularity': 64, 'monthly_listeners': 2957507, 'top_song': 'Confidence', 'genre_list': ['surf rock']},
    {'name': 'Old Mervs', 'followers': 38224, 'popularity': 54, 'monthly_listeners': 390737, 'top_song': 'Out Of Luck', 'genre_list': ['surf rock']},
    {'name': 'Ole 60', 'followers': 274546, 'popularity': 65, 'monthly_listeners': 2271426, 'top_song': 'smoke & a light', 'genre_list': ['country']},
    {'name': 'Olivia Rodrigo', 'followers': 44718230, 'popularity': 88, 'monthly_listeners': 45625465, 'top_song': 'traitor', 'genre_list': []},
    {'name': 'Orion Sun', 'followers': 394953, 'popularity': 63, 'monthly_listeners': 2588644, 'top_song': 'dirty dancer', 'genre_list': ['alternative r&b', 'bedroom pop']},
    {'name': 'Orla Gartland', 'followers': 273641, 'popularity': 53, 'monthly_listeners': 777594, 'top_song': 'Why Am I Like This?', 'genre_list': ['indie pop']},
    {'name': 'Otoboke Beaver', 'followers': 153832, 'popularity': 37, 'monthly_listeners': 71422, 'top_song': "Don't light my fire", 'genre_list': ['noise rock', 'j-rock']},
    {'name': 'Overmono', 'followers': 166241, 'popularity': 56, 'monthly_listeners': 1308244, 'top_song': 'stayinit', 'genre_list': ['uk garage', 'breakbeat']},
    {'name': 'People R Ugly', 'followers': 42322, 'popularity': 47, 'monthly_listeners': 280278, 'top_song': "What's Up?", 'genre_list': []},
    {'name': 'Prospa', 'followers': 56212, 'popularity': 54, 'monthly_listeners': 1096801, 'top_song': 'This Rhythm (feat. RAHH)', 'genre_list': []},
    {'name': 'Rachel Grae', 'followers': 213329, 'popularity': 56, 'monthly_listeners': 1178239, 'top_song': 'Different Lives', 'genre_list': []},
    {'name': 'RaeCola', 'followers': 1549, 'popularity': 13, 'monthly_listeners': 4485, 'top_song': 'U Got Dat', 'genre_list': ['baltimore club']},
    {'name': 'Ratboys', 'followers': 51835, 'popularity': 40, 'monthly_listeners': 123370, 'top_song': 'I Go Out at Night', 'genre_list': []},
    {'name': 'Ravyn Lenae', 'followers': 538932, 'popularity': 72, 'monthly_listeners': 7647105, 'top_song': 'Love Me Not', 'genre_list': ['alternative r&b']},
    {'name': 'Rebecca Black', 'followers': 166951, 'popularity': 58, 'monthly_listeners': 1038177, 'top_song': 'Salvation', 'genre_list': ['hyperpop']},
    {'name': 'Remi Wolf', 'followers': 592163, 'popularity': 67, 'monthly_listeners': 4238708, 'top_song': 'Cinderella', 'genre_list': []},
    {'name': 'ROLE MODEL', 'followers': 598172, 'popularity': 75, 'monthly_listeners': 5512373, 'top_song': 'Sally, When The Wine Runs Out', 'genre_list': ['bedroom pop']},
    {'name': 'Royel Otis', 'followers': 424895, 'popularity': 71, 'monthly_listeners': 7274375, 'top_song': 'Linger - SiriusXM Session', 'genre_list': ['indie']},
    {'name': 'RÜFÜS DU SOL', 'followers': 2028505, 'popularity': 75, 'monthly_listeners': 9464147, 'top_song': 'Innerbloom', 'genre_list': []},
    {'name': 'Sabrina Carpenter', 'followers': 20832859, 'popularity': 92, 'monthly_listeners': 67217251, 'top_song': 'Espresso', 'genre_list': []},
    {'name': 'salute', 'followers': 86006, 'popularity': 53, 'monthly_listeners': 930567, 'top_song': 'Heaven In Your Arms', 'genre_list': ['uk garage', 'stutter house']},
    {'name': 'Sam Austins', 'followers': 44567, 'popularity': 60, 'monthly_listeners': 2793085, 'top_song': 'Seasons', 'genre_list': []},
    {'name': 'Sammy Virji', 'followers': 168398, 'popularity': 65, 'monthly_listeners': 3657129, 'top_song': 'If U Need It', 'genre_list': ['uk garage', 'bassline', 'bass house', 'house']},
    {'name': 'Sierra Ferrell', 'followers': 357465, 'popularity': 63, 'monthly_listeners': 2404603, 'top_song': 'Holy Roller (feat. Sierra Ferrell)', 'genre_list': ['americana', 'alt country', 'bluegrass']},
    {'name': 'Silly Goose', 'followers': 29446, 'popularity': 33, 'monthly_listeners': 46648, 'top_song': 'Bad Behavior', 'genre_list': ['rap metal', 'nu metal', 'rap rock']},
    {'name': 'Sofia Camara', 'followers': 60040, 'popularity': 58, 'monthly_listeners': 1583851, 'top_song': 'With You (with Sofia Camara)', 'genre_list': []},
    {'name': 'STAR BANDZ', 'followers': 120455, 'popularity': 51, 'monthly_listeners': 652868, 'top_song': 'My Baby (feat. STAR BANDZ)', 'genre_list': []},
    {'name': 'Still Woozy', 'followers': 1069907, 'popularity': 66, 'monthly_listeners': 3856912, 'top_song': 'Goodie Bag', 'genre_list': ['bedroom pop']},
    {'name': 'Sunami', 'followers': 150866, 'popularity': 50, 'monthly_listeners': 263948, 'top_song': 'Weak Die First', 'genre_list': ['hardcore', 'hardcore punk', 'grindcore']},
    {'name': 'The Symposium', 'followers': 95692, 'popularity': 47, 'monthly_listeners': 249247, 'top_song': 'The Physical Attractions', 'genre_list': []},
    {'name': 'T-Pain', 'followers': 5384005, 'popularity': 80, 'monthly_listeners': 19239892, 'top_song': 'Hey Baby (Drop It to the Floor) (feat. T-Pain)', 'genre_list': []},
    {'name': 'Tanner Adell', 'followers': 116786, 'popularity': 54, 'monthly_listeners': 1179201, 'top_song': 'BLACKBIIRD', 'genre_list': []},
    {'name': 'Tape B', 'followers': 73016, 'popularity': 53, 'monthly_listeners': 683413, 'top_song': 'Gas Pedal Remix', 'genre_list': ['dubstep', 'bass music', 'riddim']},
    {'name': 'TESSLA', 'followers': 360, 'popularity': 6, 'monthly_listeners': 1024, 'top_song': 'Dream Of Me', 'genre_list': []},
    {'name': 'Torren Foot', 'followers': 25495, 'popularity': 52, 'monthly_listeners': 1074047, 'top_song': 'New Bottega', 'genre_list': ['tech house']},
    {'name': 'Torren Foot B2B Airwolf Paradise', 'followers': 23462, 'popularity': 54, 'monthly_listeners': 759400, 'top_song': 'New Bottega / Revolver', 'genre_list': ['tech house']},
    {'name': 'TWICE', 'followers': 21619739, 'popularity': 79, 'monthly_listeners': 10004161, 'top_song': 'Strategy (feat. Megan Thee Stallion)', 'genre_list': ['k-pop']},
    {'name': 'Two Friends', 'followers': 237659, 'popularity': 56, 'monthly_listeners': 1239912, 'top_song': 'If Only I (feat. Bebe Rexha)', 'genre_list': []},
    {'name': 'Tyler, The Creator', 'followers': 21067783, 'popularity': 91, 'monthly_listeners': 47578912, 'top_song': 'See You Again (feat. Kali Uchis)', 'genre_list': []},
    {'name': 'Vincent Lima', 'followers': 61037, 'popularity': 55, 'monthly_listeners': 548338, 'top_song': 'The Fire', 'genre_list': []},
    {'name': 'Viperactive', 'followers': 13906, 'popularity': 41, 'monthly_listeners': 197360, 'top_song': 'In The Cut - VIP', 'genre_list': ['riddim', 'dubstep', 'bass music', 'deathstep']},
    {'name': 'Wallows', 'followers': 2926796, 'popularity': 73, 'monthly_listeners': 8842850, 'top_song': 'Are You Bored Yet? (feat. Clairo)', 'genre_list': ['indie']},
    {'name': 'Wasia Project', 'followers': 337004, 'popularity': 57, 'monthly_listeners': 1248435, 'top_song': 'ur so pretty', 'genre_list': []},
    {'name': 'wave to earth', 'followers': 4202743, 'popularity': 76, 'monthly_listeners': 8496682, 'top_song': 'seasons', 'genre_list': []},
    {'name': 'Wild Rivers', 'followers': 278997, 'popularity': 66, 'monthly_listeners': 3069026, 'top_song': "Thinking 'Bout Love", 'genre_list': ['folk pop']},
    {'name': 'Willow Avalon', 'followers': 159575, 'popularity': 52, 'monthly_listeners': 633317, 'top_song': 'Homewrecker', 'genre_list': []},
    {'name': 'Winnetka Bowling League', 'followers': 79051, 'popularity': 46, 'monthly_listeners': 381235, 'top_song': 'Slow Dances', 'genre_list': []},
    {'name': 'Winyah', 'followers': 4078, 'popularity': 35, 'monthly_listeners': 63927, 'top_song': 'Feel It All Again', 'genre_list': []},
    {'name': 'Wunderhorse', 'followers': 157139, 'popularity': 63, 'monthly_listeners': 1367962, 'top_song': 'Teal', 'genre_list': []},
    {'name': 'Wyatt Flores', 'followers': 375373, 'popularity': 67, 'monthly_listeners': 3209598, 'top_song': "Please Don't Go", 'genre_list': ['country', 'red dirt']},
    {'name': 'xaviersobased', 'followers': 130933, 'popularity': 62, 'monthly_listeners': 497291, 'top_song': 'Impact (with xaviersobased)', 'genre_list': ['cloud rap', 'underground hip hop']},
    {'name': 'Xdinary Heroes', 'followers': 1168674, 'popularity': 63, 'monthly_listeners': 701271, 'top_song': 'Beautiful Life', 'genre_list': ['k-rock', 'k-pop']},
    {'name': 'Yana', 'followers': 24613, 'popularity': 50, 'monthly_listeners': 393556, 'top_song': 'Haunt Me', 'genre_list': []},
    {'name': 'Young Miko', 'followers': 3708755, 'popularity': 77, 'monthly_listeners': 19688691, 'top_song': 'CLASSY 101', 'genre_list': ['trap latino']},
    {'name': 'Zinadelphia', 'followers': 46537, 'popularity': 44, 'monthly_listeners': 252632, 'top_song': 'Love Language', 'genre_list': []},
    {'name': 'Zoe Ko', 'followers': 27565, 'popularity': 43, 'monthly_listeners': 177609, 'top_song': 'DIRT', 'genre_list': []},
]

# %%
test_content = {
    "copyright":"Licensed under a Creative Commons Attribution-NonCommercial 3.0 License https://creativecommons.org/licenses/by-nc/3.0/. Free for non-commercial use. Contact halvin@clashfinder.com for other uses.",
    "modified":"2025-07-23 20:21",
    "name":"Lollapalooza Chicago 2025",
    "id":"lollapalooza2025chicago",
    "url":"https://clashfinder.com/s/lollapalooza2025chicago/",
    "printAdvisory":5,
    "timezone":"US/Central",
    "tzOffset":-18000,
    "tzNote":"Start and end times are given in the timezone of the event. Offset by -tzOffset for UTC.",
    "auth":{"result":"fail","reason":"authUsername not provided"},
    "locations":[
        {
            "name":"TMobile",
            "events":[
                {"name":"Nourished by Time","short":"nouris(1)","start":"2025-07-31 13:15","end":"2025-07-31 14:00"},
                {"name":"Durand Bernarr","short":"durand(1)","start":"2025-07-31 15:00","end":"2025-07-31 16:00"},
                {"name":"Barry Can't Swim","short":"barryc(1)","start":"2025-07-31 17:00","end":"2025-07-31 18:00"},
                {"name":"Gracie Abrams","short":"gracie(1)","start":"2025-07-31 19:00","end":"2025-07-31 20:00"},
                {"name":"Tyler, the Creator","short":"tylerc(1)","start":"2025-07-31 21:00","end":"2025-07-31 22:00"},
                {"name":"Tanner Adell","short":"tanner(1)","start":"2025-08-01 13:15","end":"2025-08-01 14:00"},
                {"name":"Gigi Perez","short":"gigipe(1)","start":"2025-08-01 14:45","end":"2025-08-01 15:40"},
                {"name":"Foster the People","short":"foster(1)","start":"2025-08-01 16:40","end":"2025-08-01 17:40"},
                {"name":"DJO","short":"djo(1)","start":"2025-08-01 18:40","end":"2025-08-01 19:40"},
                {"name":"Olivia Rodrigo","short":"olivia(1)","start":"2025-08-01 20:40","end":"2025-08-01 22:00"},
                {"name":"Sam Austins","short":"samaus(1)","start":"2025-08-02 13:10","end":"2025-08-02 13:55"},
                {"name":"Max McNown","short":"maxmcn(1)","start":"2025-08-02 14:55","end":"2025-08-02 15:55"},
                {"name":"MARINA","short":"marina(1)","start":"2025-08-02 16:55","end":"2025-08-02 17:55"},
                {"name":"Doechii","short":"doechi(1)","start":"2025-08-02 18:55","end":"2025-08-02 19:45"},
                {"name":"Rufus du Sol","short":"rufusd(1)","start":"2025-08-02 20:45","end":"2025-08-02 22:00"},
                {"name":"Laila!","short":"laila(1)","start":"2025-08-03 13:30","end":"2025-08-03 14:15"},
                {"name":"Katseye","short":"katsey(1)","start":"2025-08-03 15:15","end":"2025-08-03 16:00"},
                {"name":"Isiah Rashad","short":"isiahr(1)","start":"2025-08-03 17:00","end":"2025-08-03 18:00"},
                {"name":"Dominic Fike","short":"domini(1)","start":"2025-08-03 19:00","end":"2025-08-03 20:00"},
                {"name":"Sabrina Carpenter","short":"sabrin(1)","start":"2025-08-03 21:00","end":"2025-08-03 22:00"}
            ]
        },
        {
            "name":"Lakeshore",
            "events":[
                {"name":"The Symposium","short":"sympos(1)","start":"2025-07-31 12:30","end":"2025-07-31 13:15"},
                {"name":"Julie","short":"julie(1)","start":"2025-07-31 14:00","end":"2025-07-31 14:55"},
                {"name":"Matt Champion","short":"mattch(1)","start":"2025-07-31 16:00","end":"2025-07-31 17:00"},
                {"name":"Magdalena Bay","short":"magdal(1)","start":"2025-07-31 18:00","end":"2025-07-31 19:00"},
                {"name":"Royel Otis","short":"royelo(1)","start":"2025-07-31 20:00","end":"2025-07-31 21:00"},
                {"name":"Dogpark","short":"dogpar(1)","start":"2025-08-01 12:30","end":"2025-08-01 13:15"},
                {"name":"Isabel Larosa","short":"isabel(1)","start":"2025-08-01 14:00","end":"2025-08-01 14:45"},
                {"name":"Ravyn Lenae","short":"ravynl(1)","start":"2025-08-01 15:40","end":"2025-08-01 16:40"},
                {"name":"Amaarae","short":"amaara(1)","start":"2025-08-01 17:40","end":"2025-08-01 18:40"},
                {"name":"Wallows","short":"wallow(1)","start":"2025-08-01 19:40","end":"2025-08-01 20:40"},
                {"name":"Winnetka Bowling League","short":"winnet(1)","start":"2025-08-02 12:25","end":"2025-08-02 13:10"},
                {"name":"Charlotte Laawrence","short":"charlo(1)","start":"2025-08-02 13:55","end":"2025-08-02 14:55"},
                {"name":"bossman dlow","short":"bossma(1)","start":"2025-08-02 15:55","end":"2025-08-02 16:55"},
                {"name":"ca7riel & paco amoroso","short":"ca7rie(1)","start":"2025-08-02 17:55","end":"2025-08-02 18:55"},
                {"name":"JPEGMAFIA","short":"jpegma(1)","start":"2025-08-02 19:45","end":"2025-08-02 20:45"},
                {"name":"Joe P","short":"joep(1)","start":"2025-08-03 12:45","end":"2025-08-03 13:30"},
                {"name":"boynextdoor","short":"boynex(1)","start":"2025-08-03 14:15","end":"2025-08-03 15:15"},
                {"name":"Mariah the Scientist","short":"mariah(1)","start":"2025-08-03 16:00","end":"2025-08-03 17:00"},
                {"name":"Finneas","short":"finnea(1)","start":"2025-08-03 18:00","end":"2025-08-03 19:00"},
                {"name":"Still Woozy","short":"stillw(1)","start":"2025-08-03 20:00","end":"2025-08-03 21:00"}
            ]
        },
        {
            "name":"Perry's",
            "events":[
                {"name":"DJ Heather","short":"djheat(1)","start":"2025-07-31 12:00","end":"2025-07-31 12:45"},
                {"name":"Torren Foot b2b Airwolf Paradise","short":"torren(1)","start":"2025-07-31 12:55","end":"2025-07-31 13:50"},
                {"name":"Azecca","short":"azecca(1)","start":"2025-07-31 14:00","end":"2025-07-31 14:55"},
                {"name":"Prospa","short":"prospa(1)","start":"2025-07-31 15:10","end":"2025-07-31 16:10"},
                {"name":"The Blessed Madonna","short":"blesse(1)","start":"2025-07-31 16:20","end":"2025-07-31 17:20"},
                {"name":"Cloonee","short":"cloone(1)","start":"2025-07-31 17:50","end":"2025-07-31 18:50"},
                {"name":"Mau P","short":"maup(1)","start":"2025-07-31 19:00","end":"2025-07-31 20:00"},
                {"name":"Dom Dolla","short":"domdol(1)","start":"2025-07-31 20:30","end":"2025-07-31 21:45"},
                {"name":"Mary Droppinz","short":"marydr(1)","start":"2025-08-01 12:00","end":"2025-08-01 12:35"},
                {"name":"Hex Cougar","short":"hexcou(1)","start":"2025-08-01 12:40","end":"2025-08-01 13:15"},
                {"name":"Viperactive","short":"vipera(1)","start":"2025-08-01 13:30","end":"2025-08-01 14:15"},
                {"name":"Murda Beatz","short":"murdab(1)","start":"2025-08-01 14:30","end":"2025-08-01 15:15"},
                {"name":"ALLEYCVT","short":"alleyc(1)","start":"2025-08-01 15:30","end":"2025-08-01 16:15"},
                {"name":"Bunt.","short":"bunt(1)","start":"2025-08-01 16:30","end":"2025-08-01 17:30"},
                {"name":"Tape B","short":"tapeb(1)","start":"2025-08-01 18:00","end":"2025-08-01 19:00"},
                {"name":"ISOXO","short":"isoxo(1)","start":"2025-08-01 19:15","end":"2025-08-01 20:15"},
                {"name":"KNOCK2","short":"knock2(1)","start":"2025-08-01 20:30","end":"2025-08-01 21:45"},
                {"name":"Tessla","short":"tessla(1)","start":"2025-08-02 12:00","end":"2025-08-02 12:35"},
                {"name":"JEV","short":"jev(1)","start":"2025-08-02 12:40","end":"2025-08-02 13:20"},
                {"name":"Daniel Allen","short":"daniel(1)","start":"2025-08-02 13:30","end":"2025-08-02 14:15"},
                {"name":"Layz","short":"layz(1)","start":"2025-08-02 14:30","end":"2025-08-02 15:15"},
                {"name":"Flux Pavilion","short":"fluxpa(1)","start":"2025-08-02 15:30","end":"2025-08-02 16:30"},
                {"name":"Dr. Fresch","short":"drfres(1)","start":"2025-08-02 16:45","end":"2025-08-02 17:45"},
                {"name":"Levity","short":"levity(1)","start":"2025-08-02 18:15","end":"2025-08-02 19:15"},
                {"name":"Chase & Status","short":"chases(1)","start":"2025-08-02 19:30","end":"2025-08-02 20:30"},
                {"name":"Two Friends","short":"twofri(1)","start":"2025-08-02 20:45","end":"2025-08-02 21:45"},
                {"name":"Raecola","short":"raecol(1)","start":"2025-08-03 12:00","end":"2025-08-03 12:30"},
                {"name":"jigitz","short":"jigitz(1)","start":"2025-08-03 12:45","end":"2025-08-03 13:30"},
                {"name":"nimino","short":"nimino(1)","start":"2025-08-03 13:45","end":"2025-08-03 14:45"},
                {"name":"Rebecca Black","short":"rebecc(1)","start":"2025-08-03 15:00","end":"2025-08-03 16:00"},
                {"name":"Marlon Hoffstadt","short":"marlon(1)","start":"2025-08-03 16:15","end":"2025-08-03 17:15"},
                {"name":"Sammy Virji","short":"sammyv(1)","start":"2025-08-03 17:45","end":"2025-08-03 18:45"},
                {"name":"Gryffin","short":"gryffi(1)","start":"2025-08-03 19:00","end":"2025-08-03 20:00"},
                {"name":"Martin Garrix","short":"martin(1)","start":"2025-08-03 20:30","end":"2025-08-03 21:45"}
            ]
        },
        {
            "name":"BMI",
            "events":[
                {"name":"Girl Tones","short":"girlto(1)","start":"2025-07-31 13:00","end":"2025-07-31 13:40"},
                {"name":"Alexsucks","short":"alexsu(1)","start":"2025-07-31 14:10","end":"2025-07-31 14:50"},
                {"name":"Yana","short":"yana(1)","start":"2025-07-31 15:20","end":"2025-07-31 16:00"},
                {"name":"Bo Staloch","short":"bostal(2)","start":"2025-07-31 16:30","end":"2025-07-31 17:10"},
                {"name":"Colby Acuff","short":"colbya(1)","start":"2025-07-31 17:40","end":"2025-07-31 18:20"},
                {"name":"xaviersobased","short":"xavier(1)","start":"2025-07-31 18:50","end":"2025-07-31 19:30"},
                {"name":"Winyah","short":"winyah(1)","start":"2025-08-01 13:00","end":"2025-08-01 13:40"},
                {"name":"Cassandra Coleman","short":"cassan(1)","start":"2025-08-01 14:10","end":"2025-08-01 14:50"},
                {"name":"Caroline Kingsbury","short":"caroli(1)","start":"2025-08-01 15:20","end":"2025-08-01 16:00"},
                {"name":"Midnight Generation","short":"midnig(1)","start":"2025-08-01 16:30","end":"2025-08-01 17:10"},
                {"name":"Carol Ades","short":"carola(2)","start":"2025-08-01 17:40","end":"2025-08-01 18:20"},
                {"name":"Star Bandz","short":"starba(1)","start":"2025-08-01 18:50","end":"2025-08-01 19:30"},
                {"name":"Eddie and the Getaway","short":"eddiea(1)","start":"2025-08-02 13:00","end":"2025-08-02 13:40"},
                {"name":"Carter Vail","short":"carter(1)","start":"2025-08-02 14:10","end":"2025-08-02 14:50"},
                {"name":"Rachel Grae","short":"rachel(1)","start":"2025-08-02 15:20","end":"2025-08-02 16:00"},
                {"name":"Junior Varsity","short":"junior(1)","start":"2025-08-02 16:30","end":"2025-08-02 17:10"},
                {"name":"Zoe Ko","short":"zoeko(1)","start":"2025-08-02 17:40","end":"2025-08-02 18:20"},
                {"name":"People R Ugly","short":"people(1)","start":"2025-08-02 18:50","end":"2025-08-02 19:30"},
                {"name":"Benches","short":"benche(1)","start":"2025-08-03 13:00","end":"2025-08-03 13:40"},
                {"name":"Lekan","short":"lekan(1)","start":"2025-08-03 14:10","end":"2025-08-03 14:50"},
                {"name":"Sofia Camera","short":"sofiac(1)","start":"2025-08-03 15:20","end":"2025-08-03 16:00"},
                {"name":"Aliyah's Interlude","short":"aliyah(1)","start":"2025-08-03 16:30","end":"2025-08-03 17:10"},
                {"name":"Blk Odyssy","short":"blkody(1)","start":"2025-08-03 17:40","end":"2025-08-03 18:20"},
                {"name":"Graham Barham","short":"graham(1)","start":"2025-08-03 18:50","end":"2025-08-03 19:30"}
            ]
        },
        {
            "name":"Music Den",
            "events":[
                {"name":"Bo Staloch","short":"bostal(1)","start":"2025-07-31 14:00","end":"2025-07-31 14:30"},
                {"name":"Girl Tones","short":"girlto(2)","start":"2025-07-31 15:00","end":"2025-07-31 15:30"},
                {"name":"Sofia Camara","short":"sofiac1(1)","start":"2025-07-31 16:00","end":"2025-07-31 16:30"},
                {"name":"Jade LeMac","short":"jadele(2)","start":"2025-07-31 17:00","end":"2025-07-31 17:30"},
                {"name":"Yana","short":"yana(2)","start":"2025-07-31 18:00","end":"2025-07-31 18:30"},
                {"name":"Carol Ades","short":"carola(1)","start":"2025-08-01 14:00","end":"2025-08-01 14:30"},
                {"name":"Old Mervs","short":"oldmer(2)","start":"2025-08-01 15:00","end":"2025-08-01 15:30"},
                {"name":"hey, nothing","short":"heynot1(1)","start":"2025-08-01 16:00","end":"2025-08-01 16:30"},
                {"name":"Caroline Kingsbury","short":"caroli(2)","start":"2025-08-01 17:00","end":"2025-08-01 17:30"},
                {"name":"Midnight Generation","short":"midnig(2)","start":"2025-08-01 18:00","end":"2025-08-01 18:30"},
                {"name":"Landon Conrath","short":"landon(2)","start":"2025-08-02 14:00","end":"2025-08-02 14:30"},
                {"name":"NewDad","short":"newdad(2)","start":"2025-08-02 15:00","end":"2025-08-02 15:30"},
                {"name":"Winnetka Bowling League","short":"winnet(2)","start":"2025-08-02 16:00","end":"2025-08-02 16:30"},
                {"name":"Rachel Grae","short":"rachel(2)","start":"2025-08-02 17:00","end":"2025-08-02 17:30"},
                {"name":"Junior Varsity","short":"junior(2)","start":"2025-08-02 18:00","end":"2025-08-02 18:30"},
                {"name":"The Droptines","short":"dropti(2)","start":"2025-08-03 14:00","end":"2025-08-03 14:30"},
                {"name":"Joe P","short":"joep(2)","start":"2025-08-03 15:00","end":"2025-08-03 15:30"},
                {"name":"The Criticals","short":"critic(2)","start":"2025-08-03 16:00","end":"2025-08-03 16:30"},
                {"name":"Vincent Lima","short":"vincen(2)","start":"2025-08-03 17:00","end":"2025-08-03 17:30"},
                {"name":"flowerovlove","short":"flower1(2)","start":"2025-08-03 18:00","end":"2025-08-03 18:30"}
            ]
        },
        {
            "name":"Backyard",
            "events":[
                {"name":"Mr. Shaw","short":"mrshaw(1)","start":"2025-07-31 15:00","end":"2025-07-31 16:30"},
                {"name":"Mark Ambor","short":"markam(2)","start":"2025-07-31 17:00","end":"2025-07-31 17:30"},
                {"name":"Deroza dj set","short":"deroza(1)","start":"2025-07-31 17:30","end":"2025-07-31 19:00"},
                {"name":"Lucky Lou","short":"luckyl(1)","start":"2025-08-01 16:00","end":"2025-08-01 17:30"},
                {"name":"Zinadelphia","short":"zinade(2)","start":"2025-08-01 18:00","end":"2025-08-01 18:30"},
                {"name":"Kupyd","short":"kupyd(1)","start":"2025-08-01 18:30","end":"2025-08-01 20:00"},
                {"name":"Heavy dj set","short":"heavyd(1)","start":"2025-08-02 15:30","end":"2025-08-02 17:00"},
                {"name":"Max Mcnown","short":"maxmcn(2)","start":"2025-08-02 17:30","end":"2025-08-02 18:00"},
                {"name":"Zillion","short":"zillio(1)","start":"2025-08-02 18:00","end":"2025-08-02 19:30"},
                {"name":"Chachi","short":"chachi(1)","start":"2025-08-03 16:00","end":"2025-08-03 17:30"},
                {"name":"Wild Rivers","short":"wildri(2)","start":"2025-08-03 18:00","end":"2025-08-03 18:30"},
                {"name":"Goo","short":"goo(1)","start":"2025-08-03 18:30","end":"2025-08-03 20:00"}
            ]
        },
        {
            "name":"Grove",
            "events":[
                {"name":"Silly Goose","short":"sillyg(1)","start":"2025-07-31 12:00","end":"2025-07-31 12:30"},
                {"name":"The Droptines","short":"dropti(1)","start":"2025-07-31 12:50","end":"2025-07-31 13:30"},
                {"name":"Black Party","short":"blackp(1)","start":"2025-07-31 13:50","end":"2025-07-31 14:30"},
                {"name":"Sunami","short":"sunami(1)","start":"2025-07-31 14:50","end":"2025-07-31 15:30"},
                {"name":"fcukers","short":"fcuker(1)","start":"2025-07-31 16:00","end":"2025-07-31 16:45"},
                {"name":"Glass Beams","short":"glassb(1)","start":"2025-07-31 17:15","end":"2025-07-31 18:00"},
                {"name":"Overmono","short":"overmo(1)","start":"2025-07-31 18:30","end":"2025-07-31 19:15"},
                {"name":"2hollis","short":"2holli(1)","start":"2025-07-31 19:45","end":"2025-07-31 20:30"},
                {"name":"xdinary heroes","short":"xdinar(1)","start":"2025-07-31 21:00","end":"2025-07-31 22:00"},
                {"name":"Jesse Detor","short":"jessed(1)","start":"2025-08-01 12:00","end":"2025-08-01 12:30"},
                {"name":"Old Mervs","short":"oldmer(1)","start":"2025-08-01 12:50","end":"2025-08-01 13:30"},
                {"name":"Hey Nothing","short":"heynot(1)","start":"2025-08-01 13:50","end":"2025-08-01 14:30"},
                {"name":"Zinadelphia","short":"zinade(1)","start":"2025-08-01 14:50","end":"2025-08-01 15:30"},
                {"name":"Orla Gartland","short":"orlaga(1)","start":"2025-08-01 16:00","end":"2025-08-01 16:45"},
                {"name":"The Dare","short":"dare(1)","start":"2025-08-01 17:15","end":"2025-08-01 18:00"},
                {"name":"Ocean Alley","short":"oceana(1)","start":"2025-08-01 18:30","end":"2025-08-01 19:15"},
                {"name":"Wyatt Flores","short":"wyattf(1)","start":"2025-08-01 19:45","end":"2025-08-01 20:30"},
                {"name":"Bladee","short":"bladee(1)","start":"2025-08-01 21:00","end":"2025-08-01 22:00"},
                {"name":"Landon Conrath","short":"landon(1)","start":"2025-08-02 12:00","end":"2025-08-02 12:30"},
                {"name":"Dua Saleh","short":"duasal(1)","start":"2025-08-02 12:50","end":"2025-08-02 13:30"},
                {"name":"Salute","short":"salute(1)","start":"2025-08-02 13:50","end":"2025-08-02 14:30"},
                {"name":"Ole 60","short":"ole60(1)","start":"2025-08-02 14:50","end":"2025-08-02 15:30"},
                {"name":"Naomi Scott","short":"naomis(1)","start":"2025-08-02 16:00","end":"2025-08-02 16:45"},
                {"name":"Orion Sun","short":"orions(1)","start":"2025-08-02 17:15","end":"2025-08-02 18:00"},
                {"name":"Bilmuri","short":"bilmur(1)","start":"2025-08-02 18:30","end":"2025-08-02 19:15"},
                {"name":"Damiano David","short":"damian(1)","start":"2025-08-02 19:45","end":"2025-08-02 20:30"},
                {"name":"MK.GEE","short":"mkgee(1)","start":"2025-08-02 21:00","end":"2025-08-02 22:00"},
                {"name":"Kaikrewsade","short":"kaikre(1)","start":"2025-08-03 12:00","end":"2025-08-03 12:30"},
                {"name":"The Criticals","short":"critic(1)","start":"2025-08-03 12:50","end":"2025-08-03 13:30"},
                {"name":"Vincent Lima","short":"vincen(1)","start":"2025-08-03 13:50","end":"2025-08-03 14:30"},
                {"name":"Willow Avalon","short":"willow(1)","start":"2025-08-03 14:50","end":"2025-08-03 15:30"},
                {"name":"La Femme","short":"femme(1)","start":"2025-08-03 16:00","end":"2025-08-03 16:45"},
                {"name":"Joey Valence & Brae","short":"joeyva(1)","start":"2025-08-03 17:15","end":"2025-08-03 18:00"},
                {"name":"Maribou State","short":"maribo(1)","start":"2025-08-03 18:30","end":"2025-08-03 19:15"},
                {"name":"Artemas","short":"artema(1)","start":"2025-08-03 19:45","end":"2025-08-03 20:30"},
                {"name":"Latin Mafia","short":"latinm(1)","start":"2025-08-03 21:00","end":"2025-08-03 22:00"}
            ]
        },
        {
            "name":"Tito's",
            "events":[
                {"name":"Jade Lemac","short":"jadele(1)","start":"2025-07-31 12:45","end":"2025-07-31 13:30"},
                {"name":"Chicago Made","short":"chicag(1)","start":"2025-07-31 14:15","end":"2025-07-31 15:00"},
                {"name":"Half-Alive","short":"halfal(1)","start":"2025-07-31 15:45","end":"2025-07-31 16:45"},
                {"name":"Role Model","short":"rolemo(1)","start":"2025-07-31 17:45","end":"2025-07-31 18:45"},
                {"name":"Alex Warren","short":"alexwa(1)","start":"2025-07-31 19:45","end":"2025-07-31 20:30"},
                {"name":"Alemeda","short":"alemed(1)","start":"2025-08-01 12:00","end":"2025-08-01 12:45"},
                {"name":"Kenny Mason","short":"kennym(1)","start":"2025-08-01 13:30","end":"2025-08-01 14:30"},
                {"name":"Del Water Gap","short":"delwat(1)","start":"2025-08-01 15:30","end":"2025-08-01 16:30"},
                {"name":"Flipturn","short":"fliptu(1)","start":"2025-08-01 17:30","end":"2025-08-01 18:30"},
                {"name":"Mary Droppinz","short":"marydr(2)","start":"2025-08-01 19:30","end":"2025-08-01 20:30"},
                {"name":"Newdad","short":"newdad(1)","start":"2025-08-02 12:15","end":"2025-08-02 13:00"},
                {"name":"Wasia Project","short":"wasiap(1)","start":"2025-08-02 13:45","end":"2025-08-02 14:30"},
                {"name":"Montel Fish","short":"montel(1)","start":"2025-08-02 15:30","end":"2025-08-02 16:30"},
                {"name":"Fujii Kaze","short":"fujiik(1)","start":"2025-08-02 17:30","end":"2025-08-02 18:30"},
                {"name":"Chicago Youth Symphony Orchestra","short":"chicag1(1)","start":"2025-08-02 19:30","end":"2025-08-02 20:30"},
                {"name":"Landon Barker","short":"landon1(1)","start":"2025-08-03 12:30","end":"2025-08-03 13:15"},
                {"name":"Wunderhorse","short":"wunder(1)","start":"2025-08-03 14:00","end":"2025-08-03 15:00"},
                {"name":"Wave to Earth","short":"waveto(1)","start":"2025-08-03 16:00","end":"2025-08-03 17:00"},
                {"name":"Ian","short":"ian(1)","start":"2025-08-03 18:00","end":"2025-08-03 19:00"},
                {"name":"Rebecca Black","short":"rebecc(2)","start":"2025-08-03 20:00","end":"2025-08-03 20:45"}
            ]
        },
        {
            "name":"Bud Light",
            "events":[
                {"name":"Ratboys","short":"ratboy(1)","start":"2025-07-31 13:30","end":"2025-07-31 14:15"},
                {"name":"Mark Ambor","short":"markam(1)","start":"2025-07-31 15:00","end":"2025-07-31 15:45"},
                {"name":"Sierra Ferrell","short":"sierra(1)","start":"2025-07-31 16:45","end":"2025-07-31 17:45"},
                {"name":"Cage the Elephant","short":"cageel(1)","start":"2025-07-31 18:45","end":"2025-07-31 19:45"},
                {"name":"Luke Combs","short":"lukeco(1)","start":"2025-07-31 20:30","end":"2025-07-31 22:00"},
                {"name":"Jane Remover","short":"janere(1)","start":"2025-08-01 12:45","end":"2025-08-01 13:30"},
                {"name":"Otoboke Beaver","short":"otobok(1)","start":"2025-08-01 14:30","end":"2025-08-01 15:30"},
                {"name":"T-Pain","short":"tpain(1)","start":"2025-08-01 16:30","end":"2025-08-01 17:30"},
                {"name":"Bleachers","short":"bleach(1)","start":"2025-08-01 18:30","end":"2025-08-01 19:30"},
                {"name":"Korn","short":"korn(1)","start":"2025-08-01 20:30","end":"2025-08-01 22:00"},
                {"name":"Kickflip","short":"kickfl(1)","start":"2025-08-02 13:00","end":"2025-08-02 13:45"},
                {"name":"Boa","short":"boa(1)","start":"2025-08-02 14:30","end":"2025-08-02 15:30"},
                {"name":"Young Miko","short":"youngm(1)","start":"2025-08-02 16:30","end":"2025-08-02 17:30"},
                {"name":"Clairo","short":"clairo(1)","start":"2025-08-02 18:30","end":"2025-08-02 19:30"},
                {"name":"Twice","short":"twice(1)","start":"2025-08-02 20:30","end":"2025-08-02 22:00"},
                {"name":"Flowerovlove","short":"flower1(1)","start":"2025-08-03 13:15","end":"2025-08-03 14:00"},
                {"name":"Wild Rivers","short":"wildri(1)","start":"2025-08-03 15:00","end":"2025-08-03 16:00"},
                {"name":"Remi Wolf","short":"remiwo(1)","start":"2025-08-03 17:00","end":"2025-08-03 18:00"},
                {"name":"The Maria","short":"maria(1)","start":"2025-08-03 19:00","end":"2025-08-03 20:00"},
                {"name":"A$AP Rocky","short":"aaproc(1)","start":"2025-08-03 20:45","end":"2025-08-03 22:00"}
            ]
        }
    ]
}

# %%
genre_source =  "https://docs.google.com/document/d/1aEJK7fxm-8BUmWOp24QD2GEpIR2YVU3pmbc23-I2vgc/edit?tab=t.0"

lolla2025 = {
    # POP
    "POP": [
        "Sabrina Carpenter", "The Dare", "KATSEYE", "Charlotte Lawrence",
        "Isabel LaRosa", "Naomi Scott", "Jade LeMac", "Zoe Ko",
        "MARINA", "Artemas", "Nourished By Time", "Caroline Kingsbury",
        "Olivia Rodrigo", "Damiano David", "Remi Wolf", "Magdalena Bay", 
        "Sam Austins", "Wasia Project", "Vincent Lima", "Bo Staloch",
        "Midnight Generation"],
    "INDIE": [
        "Dominic Fike", "Bleachers", "Wallows", "Foster the People",
        "Role Model", "Finneas", "Royel Otis", "Flipturn", "Half Alive",
        "Del Water Gap", "Alemeda", "NewDad", "Dogpark", "Joe P",
        "Winnetka Bowling League", "Carol Ades", "Carter Vail",
        "Landon Conrath", "RÜFÜS DU SOL"],
    "DREAM_POP": [
        "Gracie Abrams", "Clairo", "The Marías", "Mk.gee", "Still Woozy",
        "Wave to Earth", "Flowerovlove", "Yana", "Julie", "Alex Warren", 
        "Rachel Grae", "Sofia Camara", "Cassandra Coleman"],
    "K_POP": ["TWICE", "Boynextdoor", "Kickflip", "Fujii Kaze"],
    # ROCK
    "ROCK": ["Glass Beams", "benches", "Orla Gartland", 
             "Ole 60", "The Droptines", "Winyah",
             "Xdinary Heroes"],
    "ALT" : ["Cage the Elephant", 
            "Gigi Perez", "Wunderhorse", "hey, nothing",
            "Ratboys", "Bôa", "Old Mervs", "Jesse Detor", "Junior Varsity",
            "ALEXSUCKS", "Girl Tones", "Eddie and the Getaway"],
    "PUNK": ["Landon Barker", "People R Ugly", "Sunami", 
             "The Criticals", "Otoboke Beaver", "Bilmuri"],
    "NU_METAL": ["Korn", "Silly Goose"],
    "PSYCH_ROCK": ["DJO", "Ocean Alley", "La Femme", "The Symposium"],
    #EDM
    "HOUSE": ["Martin Garrix", "Two Friends", "The Blessed Madonna",
              "Barry Can't Swim", "Prospa", "Azzecca", "DJ Heather",
              "Tessla", "Aliyah's Interlude", "BUNT.", "Salute",
              "Nimino", "Jigitz", "Daniel Allan", "Jev", "Dom Dolla",
              "Mau P", "Cloonee", "Torren B2B Airwolf", "Raecola",
              "Chachi", "Deroza dj set", "Goo", "Heavy dj set",
              "Kupyd", "Lucky Lou", "Mr. Shaw", "Zillion"],
    "DUBSTEP": ["ISOxo", "Tape B", "Flux Pavilion", "Levity",
                "Layz", "ALLEYCVT", "Hex Cougar", "Viperactive"],
    "BASS": ["KNOCK2", "Dr. Fresch", "Gryffin", "Mary Droppinz"],
    "TECHNO": ["Marlon Hoffstadt", "Rebecca Black"],
    "DnB": ["Sammy Virji", "Overmono", "Chase & Status"],
    "DANCE": ["Fcukers", "Maribou State"],
    # RAP
    "RAP": ["Tyler, the Creator", "Doechii", "Isaiah Rashad", "Joey Valence & Brae",
        "Matt Champion", "Kenny Mason", "Kaicrewsade", "JPEGMafia", "Young Miko"],
    "TRAP": ["A$AP Rocky", "Ian", "Bossman Dlow", "Murda Beatz", "Star Bandz"],
    "EMORAP": ["Bladee", "2Hollis", "Jane Remover", "Xaviersobased"],
    # R&B
    "SOUL": ["Ravyn Lenae", "Montell Fish", "BLK Odyssy", "Lekan", "Ca7riel y Paco Amoroso"],
    "RnB": ["T-Pain", "Durand Bernarr", "Zinadelphia", "Mariah the Scientist",
            "Orion Sun", "Laila!", "Black Party", "Dua Saleh", "Latin Mafia", "Amaarae"],
    # OTHER
    "COUNTRY": ["Luke Combs", "Wyatt Flores", "Max McNown", "Willow Avalon",
                "Colby Acuff", "Graham Barham", "Tanner Adell"],
    "FOLK": ["Sierra Ferrell", "Wild Rivers", "Mark Ambor"],
    "CLASSICAL" : ["Chicago Youth Orchestra"],
    "OTHER": ["Chicago Made"],
}

forest2025 = {
    "N/A": ["SARA LANDRY","VINTAGE CULTURE","LIQUID STRANGER","JUSTICE","TIëSTO","LOUIS THE CHILD","DIMENSION","1991",
    "CLOONEE","ZEDS DEAD","DISCLOSURE","BARRY CAN'T SWIM","FISHER","KHRUANGBIN","OF THE TREES","MOCHAKK","THE STRING CHEESE INCIDENT",
    "ARC DE SOLEIL","AVALON EMERSON","BBNO$","BLOND:ISH","BUNT.","CARIBOU","CONFIDENCE MAN","CRANKDAT","DAPHNI","DJ HEARTSTRING",
    "DOMBRESKY","FCUKERS","GASHI","GORDO","HAMDI","HAYLA","INTERPLANETARY CRIMINAL","JADE CICADA","JERSEY","JOEY VALENCE & BRAE",
    "LILLY PALMER","LOCO DICE","MERSIV","MIKE POSNER","MINDCHATTER","NIA ARCHIVES","NOTION","RAY VOLPE","SUB FOCUS","TAPE B",
    "THE KNOCKS","DRAGONETTE","TRACTORBEAM","WILL CLARKE","ZINGARA","1TBSP","33 BELOW","AHEE","AHMED SPINS","ALEX WANN","ARUSHI JAIN",
    "BALTHVS","BAMBII","BASSTRIPPER","BELTRAN","BIIANCO","CULTURE SHOCK","CVBZ","CYDNEE WITH A C","DIXON'S VIOLIN","EATER", "EVENING ELEPHANTS",
    "GORILLAT","H&RRY","HAUTE & FREDDY","INFEKT","JERRO","JON CASEY","KANINE","LOODS","LOOFY","LOVE,SHAUN","LOWDOWN BRASS BAND",
    "MAIN PHASE","MAZ","MIDNIGHT GENERATION","MOODY GOOD","NASAYA","NIMINO","ØTTA","POCKET","PRETTY PINK","RIORDAN","ROI TURBO","SAXSQUATCH",
    "SAY SHE SHE","SHIMA","SOTA","SPOONE","TAAHLIAH","TAIKI NULIGHT","THE FREE LABEL","THE PHILHARMONIK","THE STRIKE","VILLAGER","WAKYIN",
    "WONKYWILLA","WRECKNO","YDG"]
    } 
     
coachella2025 = { 
    "N/A": ["Above & Beyond", "A. G. Cook", "Alok", "Amaarae", "Amelie Lens", "Amémé", "Amyl and the Sniffers", "Anitta", "Arca",  
            "Artemas", "Austin Millz", "Basement Jaxx", "Beabadoobee", "The Beaches", "Beltran", "Ben Böhmer", "Benson Boone", "Beth Gibbons", 
            "BigXthaPlug", "Blonde Redhead", "Bob Vylan", "Boris Brejcha", "Ca7riel & Paco Amoroso", "Charli XCX", "Chris Lorenzo", 
            "Chris Stussy", "Chase & Status", "Circle Jerks", "Clairo", "Coco & Breezy", "Damian Lazarus", "The Dare", "Darkside", "Dennis Cruz", 
            "Desiree Triplosm", "Disco Lines", "Dixon x Jimi Jules", "DJ Gigola", "Djo", "D4vd", "El Malilla", "Eli Brown", "Enhyphen", "Erez", 
            "Eyedress", "Fcukers", "FKA twigs", "Francis Mercier", "Gel", "Ginger Root", "Glixen", "Glass Beams", "Glorilla", "The Go-Go's", "Green Day", 
            "Gustavo Dudamel & LA Phil", "Haai", "Hanumankind", "HiTech", "Hope Tala", "Horsegiirl", "Indira Paganotto", "Indo Warehouse", 
            "Infected Mushroom", "Interplanetary Criminal", "Ivan Cornejo", "Japanese Breakfast", "Jennie", "Jessie Murph", "Jimmy Eat World", 
            "Judeline", "Julie", "Junior H", "Keinemusik", "Keshi", "Klangkuenstler", "Kneecap", "Kraftwerk", "Kumo 99", "Lady Gaga", "Layton Giordani", 
            "Lisa", "Lola Young", "Los Mirlos", "Maribou State", "The Mariás", "Marina", "Mau P", "Medium Build", "Megan Thee Stallion", "Meute", 
            "Miike Snow", "Mind Against x Massano", "Missy Elliott", "Mohamed Ramadan", "Moon Boots", "Muni Long", "Mustard", "Misfits", 
            "Parcels", "Parisi", "Pete Tong x Ahmed Spins", "Polo & Pan", "Post Malone", "Prison Affair", "The Prodigy", "Ravyn Lenae", "Rawayana", 
            "Rema", "Saint Jhn", "Salute", "Sam Fender", "Sammy Virji", "Sara Landry", "Seun Kuti & Egypt 80", "Shaboozey", "Shermanology", "Shoreline Mafia", 
            "Snow Strippers", "Soft Play", "Sparrow & Barbossa", "Speed", "Still Woozy", "Talón", "Thee Sacred Souls", "Three 6 Mafia", "Tink", "Tinlicker", 
            "Together Pangea", "Tops", "T-Pain", "Travis Scott", "Tripolism", "Ty Dolla $ign", "Tyla", "Underscores", "Viagra Boys", "Vintage Culture", 
            "Vs Self", "VTSS", "Wisp", "XG", "Yeat", "Yo Gabba Gabba!", "Yulia Niko", "Zedd", "2hollis", "4batz"] 
} 
     
     
genreDict = lolla2025 
     
if genreDict != lolla2025: 
    IGNORE_STAGES = True

# %%
duoActs = {"Torren B2B Airwolf" : ["Torren Foot", "Airwolf Paradise"]}
forClashFinder = {"Chicago Youth Symphony Orchestra" : "Chicago Youth Orchestra", "Torren Foot B2B Airwolf Paradise" : "Torren B2B Airwolf"} # k:v is name in clash finder : name in genre list

# %%
def get_artist(artist_name, client_id, client_secret):
    # Remove single quotes to avoid search issues
    top_track_not_found = 0
    global sp
    first_match = False
    if "'" in artist_name:
        artist_name = artist_name.replace("'", "")
        first_match = True
    
    if sp is None:
        auth_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
        sp = spotipy.Spotify(auth_manager=auth_manager)
    
    result = sp.search(q=f'artist:{artist_name}', type='artist')
    artist_results = result.get('artists', {}).get('items', [])
    
    if not artist_results:
        if PRINT_SEARCH_RESULTS:
            print(f"FAILED TO FIND: {artist_name}")
        return None, top_track_not_found
    
    # Extract artist names for debugging
    names_in_search = [artist['name'] for artist in artist_results]
    # Find the best match
    for i, artist in enumerate(artist_results):
        if first_match:
            if PRINT_SEARCH_RESULTS:
                top_tracks = sp.artist_top_tracks(artist['id'], country='US')
                top_track = top_tracks['tracks'][0]['name'] if top_tracks['tracks'] else top_track_not_found
                print(f"Best for {artist_name} is {artist['name']} | Chose element {i} in {names_in_search} | Top Track is: {top_track}")
            return artist, top_track
        
        if artist['name'].upper() == artist_name.upper():
            if PRINT_SEARCH_RESULTS:
                top_tracks = sp.artist_top_tracks(artist['id'], country='US')
                top_track = top_tracks['tracks'][0]['name'] if top_tracks['tracks'] else top_track_not_found
                print(f"Found {artist['name']} | Chose element {i} in {names_in_search} | Top Track is: {top_track}")
            return artist, top_track
    
    # No exact match found
    if PRINT_SEARCH_RESULTS:
        print(f"FAILED TO FIND: {artist_name}, BUT FOUND {names_in_search}")
    
    return None, top_track_not_found

# %%
# Simpler functions

def get_client_credentials(file_path="creds.json"):
    try:
        with open(file_path, 'r') as file:
            data = json.load(file)
            client_id = data['client_id']
            client_secret = data['client_secret']
            return client_id, client_secret
    except (KeyError, FileNotFoundError, json.decoder.JSONDecodeError) as e:
        print(f"No Spotify credentials found. {e}. Setting all acts to a popularity of 0.")
        return None, None
    

def rank_artists_by_popularity(artists):
    # Sort artists by popularity in descending order
    sorted_artists = sorted(artists, key=lambda x: x['followers'], reverse=True)
    artist_ranks = {}
    # Assign ranks starting from 1
    for rank, artist in enumerate(sorted_artists, start=1):
        artist_ranks[artist['name']] = rank
    return artist_ranks

def findGenre(act):
    for key in genreDict:
        for i in genreDict[key]:
            if i.upper() == act.upper():
                return key
    return "GENRE_COUNT"

def get_ranking(artists, name):
    for artist in artists:
        if artist['name'].lower() == name.lower():
            return artist['overall']
    return 0

def set_pop_follow_manually(artists, name, pop, follower):
    for artist in artists:
        if artist['name'].lower() == name.lower():
            artist['popularity'] = pop
            artist['followers'] = follower
    return artists

def get_url_content(url):
    try:
        ua = UserAgent()
        user_agent = ua.chrome
        response = requests.get(url, headers={'User-Agent': user_agent}, verify=False)
        response.raise_for_status()
        return response.json()
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")
        return None

def get_artist_followers_popularity(artist_name, client_id, client_secret):
    if findGenre(artist_name) == GENRE_DEFAULT:
        return 0,0,0,[], True
    artist_info, top_song = get_artist(artist_name, client_id, client_secret)
    if artist_info is None:
        return 0,0,0,[], False
    followers = artist_info['followers']['total']
    popularity = artist_info['popularity']
    genre_list = artist_info['genres']
    return followers, popularity, top_song, genre_list, True

def strip_word(text, words_to_remove, startsWithOnly=False):
    if startsWithOnly:
        for word in words_to_remove:
            if text.lower().startswith(f"{word.lower()} "):
                return text[len(word)+1:]
        return text
    words = text.split()
    stripped_words = [word for word in words if word.lower() not in map(str.lower, words_to_remove)]
    stripped_text = ' '.join(stripped_words)
    return stripped_text

def writeAndPrint(file, text):
    file.write(f"{text}\n")
    if MAKE_ARR_FILE == 2:
        print(text)
        
def get_value_for_artist(wanted_act, key, array):
    for artist in array:
        if artist['name'] == wanted_act:
            return artist[key]
    return 0

# %%
# More complex functions

def get_html_data(content):
    fullData = {}
    date_str = "%Y-%m-%d %H:%M"
    locations = content.get('locations')
    for venue in locations:
        stage_name = venue.get('name')
        events = venue.get('events')
        for act in events:
            artist = act.get('name')
            start_time = datetime.strptime(act.get('start'), date_str)
            end_time = datetime.strptime(act.get('end'), date_str)
            act_info = {"stage" : stage_name, "start_time" : start_time, "end_time" : end_time}
            if artist in fullData:  # For when an act has multiple sets
                if isinstance(fullData[artist], dict):
                    fullData[artist] = [fullData[artist]]
                fullData[artist].append(act_info)
            else:
                fullData[artist] = act_info
    return fullData


def dates_to_act(act, day_info, genre_list, element = 0):
    defaultStart = datetime(2024, 6, 20, 15, 0)
    defaultEnd = datetime(2024, 6, 20, 16, 0)
    if act not in genre_list:
        return STAGE_DEFAULT, defaultStart, defaultEnd, 1
    
    datInfoAct = day_info[act]
    timesTheyPlay = 1
    if isinstance(datInfoAct, list):
        timesTheyPlay = len(datInfoAct)
        datInfoAct = datInfoAct[element]
    stageToSearch = datInfoAct.get("stage")
    if stageToSearch is None:
        stage = None
    else:
        stageToSearch = stageToSearch.upper()
        stage = difflib.get_close_matches(stageToSearch, STAGES, n=1)
    if not stage:
        stage = f"[{stageToSearch}]"  # Returns the stage found, around curly brackets if it couldn't be matched in the list
    else:
        stage = stage[0]
    return stage, datInfoAct["start_time"], datInfoAct["end_time"], timesTheyPlay

# %%
def popularity_sort(popList):
    if not popList:
        return popList
    use_monthly_listens = "monthly_listeners" in popList[0]
    if use_monthly_listens:
        pop_weights = [0.4, 0.3, 0.3]  # populary, follower, monthly listens 
    else:
        pop_weights = [0.7, 0.3, 0]  # populary, follower, N/A
    maxPop = max(max(artist['popularity'] for artist in popList), 1)
    maxFol = max(max(artist['followers'] for artist in popList), 1)
    if use_monthly_listens:
        maxMonLis = max(max(artist['monthly_listeners'] for artist in popList), 1)
    else:
        fol_pop_ratio = int((pop_weights[0] / pop_weights[1]) * (maxFol / maxPop))
        print(f"Ratio for prioritizing followers to popularity: {fol_pop_ratio} followers for 1 pop")
    for pop in popList:
        popPercent = pop['popularity']/maxPop
        folPercent = pop['followers']/maxFol
        monLisPercent = pop['monthly_listeners']/maxMonLis if use_monthly_listens else 0
        values = [popPercent, folPercent, monLisPercent]
        pop["fullPop"] = sum(v * w for v, w in zip(values, pop_weights))
    popList = sorted(popList, key=lambda x: x["fullPop"], reverse=True)
    for i, artist in enumerate(popList):
        artist['overall'] = i + 1 
    return popList

# %%
def getFullArray(listActs):
    # Spits out the array of acts in alphabetically order
    duo_mult = 1.2  # Since duos are more hype, add a multiplier to their popularity and follower averages
    listActsPop = []
    listActsNotFound = []
    listActsInListDuos = []
    client_id, client_secret = get_client_credentials()
    if client_id is None and client_secret is None:  # If there aren't any Spotify credentials, just set the popularity of all acts to zero
        for act in listActs:
            listActsPop.append({'name':act, 'followers' : 0, "popularity" : 0})
        return listActsPop
    for act in listActs:
        act_spot = duoActs.get(act, act)
        if isinstance(act_spot,list):
            listActsInListDuos.append(act)
            continue # We'll get and average the duos later.
        followers, popularity, top_song, genre_list, found = get_artist_followers_popularity(act_spot, client_id, client_secret)
        listActsPop.append({'name':act, 'followers' : followers, "popularity" : popularity, "top_song" : top_song, "genre_list" : genre_list})
        if not found:
            listActsNotFound.append(act_spot)
    # This logic is to average duos
    for duo in duoActs:
        if duo not in listActsInListDuos:
            continue
        artists = duoActs[duo]
        if not isinstance(artists,list):
            continue
        followers = 0
        popularity = 0
        genre_list = []
        for artist in artists:
            fol, pop, _, genres, found = get_artist_followers_popularity(artist, client_id, client_secret)
            genre_list.extend(genres)
            followers += fol
            popularity += pop
        followers = int((followers / len(artists)) * duo_mult)
        popularity = int((popularity / len(artists)) * duo_mult)
        listActsPop.append({'name':duo, 'followers' : followers, "popularity" : popularity, "top_song" : "N/A", "genre_list" : genre_list})
        if not found:
            listActsNotFound.append(act_spot)
    if PRINT_SEARCH_RESULTS and len(listActsNotFound) > 0:
        print(f"Unable to find the following Acts in Spotify: {listActsNotFound}")            
    return listActsPop

# %%
def print_md_lst(sorted_listing, genre_list, day_info):
    displayStage = True if day_info else False
    displayTopSong = 'top_song' in sorted_listing[0]
    displayGenre = 'genre_list' in sorted_listing[0]
    displayMonLis = 'monthly_listeners' in sorted_listing[0]
    numTitle = "Num"
    actTitle = "Act"
    popTitle = "Popularity"
    folTitle = "Followers"
    monLisTitle = "Monthly Listeners"
    genreTitle = "Genre"
    topSongTitle = "Popular Song"
    stgTitle = "Stage"
    longestNum = len(numTitle) + 2
    longestAct = len(actTitle) + 2
    longestPop = len(popTitle) + 2
    longestFol = len(folTitle) + 2
    longestSng = len(topSongTitle) + 2
    longestGen = len(genreTitle) + 2
    longestStg = len(stgTitle) + 2
    longestMonLis = len(monLisTitle) + 2
    stageDict = {}
    for item in sorted_listing:
        if displayStage:
            stage, _, _, _ = dates_to_act(item['name'], day_info, genre_list)
            if stage is False:
                continue
            stageDict[item['name']] = stage
        longestAct = max(longestAct, len(item['name']))
        longestPop = max(longestPop, len(str(item['popularity'])))
        longestFol = max(longestFol, len(str(item['followers'])))
        if displayMonLis:
            longestMonLis = max(longestMonLis, len(str(item['monthly_listeners'])))
        if displayGenre:
            if not (isinstance(item['genre_list'], str)):
                item['genre_list'] = "-" if not item['genre_list'] else item['genre_list'][0]
            longestGen = max(longestGen, len(str(item['genre_list'])))
        if displayTopSong:
            top_song = str(item['top_song'])
            if ")" in top_song: # If you can't make your song title work after one set of paranthesis, you don't deserve more text.
                item['top_song'] = top_song.split(')')[0] + ')'
            longestSng = max(longestSng, len(str(item['top_song'])))
        if displayStage:
            longestStg = max(longestStg, len(stage))
    printText = f"| {numTitle: ^{longestNum}} | {actTitle: ^{longestAct}} | {popTitle : ^{longestPop}} | {folTitle : ^{longestFol}} |"
    if displayMonLis:
        printText += f" {monLisTitle : ^{longestMonLis}} |"
    if displayGenre:
        printText += f" {genreTitle : ^{longestGen}} |"
    if displayTopSong:
        printText += f" {topSongTitle : ^{longestSng}} |"
    if displayStage:
        printText += f" {stgTitle : ^{longestStg}} |"
    print(printText)
    printText = f"| {'-' * longestNum} | {'-' * longestAct} | {'-' * longestPop} | {'-' * longestFol} |"
    if displayMonLis:
        printText += f" {'-' * longestMonLis} |"
    if displayGenre:
        printText += f" {'-' * longestGen} |"
    if displayTopSong:
        printText += f" {'-' * longestSng} |"
    if displayStage:
        printText += f" {'-' * longestStg} |"
    print(printText)
    for item in sorted_listing:
        act = item['name']
        popularity = item['popularity']
        followers = item['followers']
        overall = item['overall']
        printText = f"| {overall : ^{longestNum}} | {act : ^{longestAct}} | {popularity : ^{longestPop}} | {followers : ^{longestFol}} |"
        if displayMonLis:
            monthly_listeners = item['monthly_listeners']
            printText += f" {monthly_listeners : ^{longestMonLis}} |"
        if displayGenre:
            genre = item['genre_list']
            printText += f" {genre : ^{longestGen}} |"
        if displayTopSong:
            top_song = item['top_song']
            printText += f" {top_song : ^{longestSng}} |"
        if displayStage:
            stage = stageDict[act]
            printText += f" {stage : ^{longestStg}} |"
        print(printText)

# %%
replaceWords = {
                "RUFUS" : "R;F;S",
                "BOA" : "B:A",
                "A" : "a",
                "D" : "d",
                "." : "_",
                "&" : "`n",
#                "M" : "N%",
#                "W" : "WJ"
                }

def get_name_to_display(act, i=0, maxDisplayLen=None):
    actToDisp = unidecode(act)
    actToDisp = strip_word(actToDisp,["The"], True)
    actToDisp = actToDisp.upper()
    for was, want in replaceWords.items():
        actToDisp = actToDisp.replace(was, want)
    if i > 0:
        actToDisp = f"{actToDisp} {i+1}"
    if maxDisplayLen is not None:
        actToDisp = f"{actToDisp[:maxDisplayLen]}"
    actToDisp = f"{actToDisp :<6}"  # <6 makes it so text that won't fill the whole watch screen will be filled with spaces
    return actToDisp

# %%
def print_array_for_watch(listActs, sorted_listing, day_info, filename, genre_list):
    enum_txt_start = 'FESTIVAL_SCHEDULE_'
    if not day_info:
        print("Cannot print date array for watch; no date info found")
        return
    maxDisplayLen = None  # If None, then use the max length of the options, but 21 is a good option too.
    with open(f'{filename}.txt', 'w') as f:
        artistDateNotFound = []
        writeAndPrint(f, f"// Genre - {genre_source}")
        writeAndPrint(f, f"// Line-up - {URL}")
        writeAndPrint(f, '#include "festival_schedule_face.h"')
        writeAndPrint(f, "")
        totalActs = 0
        listActsPrint = []
        for act in listActs:       
            stage, start, end, timesPerformed = dates_to_act(act, day_info, genre_list, element=0)
            order_single_act_performances = []
            for i in range(timesPerformed):
                stage, start, end, _ = dates_to_act(act, day_info, genre_list, element=i)
                if stage == STAGE_DEFAULT:
                    artistDateNotFound.append(act)
                    continue
                order_single_act_performances.append({'start':start, 'end':end, 'stage':stage})
            order_single_act_performances.sort(key=lambda x: STAGES.index(x['stage']))
            for i, performance in enumerate(order_single_act_performances):
                actToDisp = get_name_to_display(act, i, maxDisplayLen)
                listActsPrint.append({'dispAct': actToDisp, 'act': act, 'start': performance['start'], 'end': performance['end'], 'stage': performance['stage']})
                totalActs += 1
        if maxDisplayLen is None:
            arrLenSchedule = len(max(listActsPrint, key=lambda x: len(x['dispAct']))['dispAct']) + 2  # +2 for padding/EOL
            arrActLongestSchedule = max(listActsPrint, key=lambda x: len(x['dispAct']))['dispAct']
            print(f"Set festival_schedule_t.artist's length to {arrLenSchedule} due to {arrActLongestSchedule}")
        listActsPrint = sorted(listActsPrint, key=lambda d: d['dispAct'].lstrip().lower())
        writeAndPrint(f, f"#define FESTIVAL_SCHEDULE_NUM_ACTS {totalActs}")
        writeAndPrint(f, "")
        writeAndPrint(f, "const festival_schedule_t festival_acts[FESTIVAL_SCHEDULE_NUM_ACTS + 1]=")
        writeAndPrint(f, "{")
        for actData in listActsPrint:     
            writeAndPrint(f, "    {")
            writeAndPrint(f, f'        .artist = "{actData["dispAct"]}",')
            writeAndPrint(f, f'        .stage = {enum_txt_start}{actData["stage"].upper()},')
            writeAndPrint(f, f'        .start_time = {{.unit.year = {actData["start"].year - 2020}, .unit.month = {actData["start"].month}, .unit.day = {actData["start"].day}, .unit.hour = {actData["start"].hour}, .unit.minute = {actData["start"].minute}}},')
            writeAndPrint(f, f'        .end_time = {{.unit.year = {actData["end"].year - 2020}, .unit.month = {actData["end"].month}, .unit.day = {actData["end"].day}, .unit.hour = {actData["end"].hour}, .unit.minute = {actData["end"].minute}}},')
            writeAndPrint(f, f'        .genre = {enum_txt_start}{findGenre(actData["act"])},')
            writeAndPrint(f, f'        .popularity = {get_ranking(sorted_listing, actData["act"])}')
            writeAndPrint(f, "    },")
        writeAndPrint(f, '    [FESTIVAL_SCHEDULE_NUM_ACTS]  = { //Fall back')
        writeAndPrint(f, '        .artist = "No Act",')
        writeAndPrint(f,f'        .stage = {enum_txt_start}STAGE_COUNT,')
        writeAndPrint(f, '        .start_time = {.unit.year = 0, .unit.month = 0, .unit.day = 0, .unit.hour = 0, .unit.minute = 0},')
        writeAndPrint(f, '        .end_time = {.unit.year = 63, .unit.month = 15, .unit.day = 31, .unit.hour = 31, .unit.minute = 63},')
        writeAndPrint(f,f'        .genre = {enum_txt_start}GENRE_COUNT,')
        writeAndPrint(f, '        .popularity = 0')
        writeAndPrint(f, '    }')
        writeAndPrint(f, '};')
    
    if PRINT_SEARCH_RESULTS and artistDateNotFound:
        print(f"\nFAILED TO FIND DATE INFO FOR {artistDateNotFound}\n")

# %%
if IGNORE_STAGES:
    day_info = {}
else:
    html_str = test_content if USE_TEST_ARR else get_url_content(URL)
    day_info = get_html_data(html_str)
    day_info = {key.split(" (")[0]: value for key, value in day_info.items()}
# Out:
# /home/ubuntu/Git/sensorwatch/Sensorwatch/utils/festival_act_popularity_sorter/venv/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'clashfinder.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
listActs = []
for key in genreDict:
    for i in genreDict[key]:
        listActs.append(i)
listActs = sorted(listActs, key=lambda x: x.lower().replace("the ",""))
in_genre_list = []
not_in_genre_list = []

day_info_keys = day_info.keys()

for key in list(day_info_keys):
    if key in forClashFinder.keys():
        val = forClashFinder[key]
        day_info[val] = day_info.pop(key)

for actDate in list(day_info_keys):
    actInDates = difflib.get_close_matches(actDate.upper(), list(map(lambda x: x.upper(), listActs)), n=1)
    if actInDates:
        actInDates = actInDates[0]
        for key1 in listActs:
            if key1.upper() == actInDates:
                day_info[key1] = day_info.pop(actDate)
                in_genre_list.append(key1)
                break
    else:
        not_in_genre_list.append(actDate)
        
in_genre_list = sorted(in_genre_list, key=lambda x: x.lower().replace("the ", "") if x[0].startswith("the ") else x[0].lower())
not_in_genre_list = sorted(not_in_genre_list, key=lambda x: x.lower().replace("the ", "") if x[0].startswith("the ") else x[0].lower())
listActsPop = testPop if USE_TEST_ARR else getFullArray(listActs)
listActsPopMissing = [] if USE_TEST_ARR else getFullArray(not_in_genre_list)
# Out:
# Found 2hollis | Chose element 0 in ['2hollis', '2hollis', '2hollis', '2hollis', '2hollis', '2Hollis', '2hollis'] | Top Track is: poster boy
# Found A$AP Rocky | Chose element 0 in ['A$AP Rocky', 'A$ap, Rocky & iHu$tla'] | Top Track is: I Smoked Away My Brain (I'm God x Demons Mashup) (feat. Imogen Heap & Clams Casino)
# Found Alemeda | Chose element 0 in ['Alemeda'] | Top Track is: Chameleon
# Found Alex Warren | Chose element 0 in ['Alex Warren', 'warren alex bafens', 'Warren Alexander', 'Alex Warren', 'Alex Warren', 'Christopher Warren-Green/Alexander Balanescu/Roger Chase/Douglas Cummings/London Chamber Orchestra', 'Alexis Danielle Warren', 'Gordon Hunt/Michael Collins/Meyrick Alexander/Michael Thompson/London Chamber Orchestra/Christopher Warren-Green', 'Donna Hazelton/Matthew Goodgame/Warren Sollars/Rebecca Dent/Caroline Graham/Craig Berry/Debralee Burns/Alex Hogg/Kerry Newton/Mike Noble/Air Studios Orchestra/Gareth Valentine'] | Top Track is: Ordinary
# ...

# %%
if SORT_POP_BY_FOLLOWERS:  
    sortKey = lambda x: (x['followers'])
    sorted_listing = sorted(listActsPop, key=sortKey, reverse=True)
    sorted_listing_missing = sorted(listActsPopMissing, key=sortKey, reverse=True)
else:
    sortKey = lambda x: (x['popularity'], x['followers']) # Sort by Spotify popularity w/ followers being the tie-breaker
    sorted_listing = sorted(listActsPop, key=sortKey, reverse=True)
    sorted_listing = popularity_sort(sorted_listing)
    sorted_listing_missing = sorted(listActsPopMissing, key=sortKey, reverse=True)
    sorted_listing_missing = popularity_sort(sorted_listing_missing)
    
if PRINT_RANKINGs: 
    print_md_lst(sorted_listing, in_genre_list, day_info)
    if sorted_listing_missing:
        print("\r\n\r\nAND THESE WERE MISSING")
        print_md_lst(sorted_listing_missing, not_in_genre_list, day_info)
    
if MAKE_ARR_FILE:
    print_array_for_watch(listActs, sorted_listing, day_info ,"festival_schedule_arr", in_genre_list)
    if sorted_listing_missing:
        print_array_for_watch(not_in_genre_list, sorted_listing_missing, day_info, "missing_festival_schedule_arr", not_in_genre_list)
# Out:
# Ratio for prioritizing followers to popularity: 1183322 followers for 1 pop
# |  Num  |           Act           |  Popularity  |  Followers  |        Genre         |                      Popular Song                      |   Stage   |
# | ----- | ----------------------- | ------------ | ----------- | -------------------- | ------------------------------------------------------ | --------- |
# |   1   |     Olivia Rodrigo      |      89      |  47163843   |          -           |                        traitor                         | T_MOBILE  |
# |   2   |   Tyler, the Creator    |      93      |  23115006   |          -           |            See You Again (feat. Kali Uchis)            | T_MOBILE  |
# |   3   |    Sabrina Carpenter    |      92      |  24223127   |          -           |                        Manchild                        | T_MOBILE  |
# ...

# %%
# Show Coorelation
import pandas as pd
df = pd.DataFrame(sorted_listing)
items = ['monthly_listeners', 'popularity', 'followers'] if "monthly_listeners" in sorted_listing[0] else ['popularity', 'followers']
correlation = df[items].corr()
print(correlation)
# Out:
#             popularity  followers
# popularity    1.000000   0.393137
# followers     0.393137   1.000000
